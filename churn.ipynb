# %% [markdown]
# <a href="https://colab.research.google.com/github/pushpa987/CODSOFT/blob/main/churn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df = pd.read_csv("/content/Churn_Modelling.csv")

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.drop(columns = ['CustomerId','Surname','RowNumber'],inplace=True)

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df['Geography'].value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Male      5457
# Female    4543
# Name: Gender, dtype: int64

# %%
df = pd.get_dummies(df,columns=['Geography','Gender'],drop_first=True)

# %%
df.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0               1        101348.88       1                  0
# 1               1        112542.58       0                  0
# 2               0        113931.57       1                  0
# 3               0         93826.63       0                  0
# 4               1         79084.10       0                  0
#
#    Geography_Spain  Gender_Male
# 0                0            0
# 1                1            0
# 2                0            0
# 3                0            0
# 4                1            0

# %%
X = df.drop(columns=['Exited'])
y = df['Exited']

# %%
X.shape
# Out:
# (10000, 11)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train.shape
# Out:
# (8000, 11)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_train_trf = scaler.fit_transform(X_train)
X_test_trf = scaler.fit_transform(X_test)

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(11,activation='sigmoid',input_dim=11))
model.add(Dense(11,activation='sigmoid'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 11)                132
#
#  dense_1 (Dense)             (None, 11)                132
#
#  dense_2 (Dense)             (None, 1)                 12
#
# =================================================================
# Total params: 276 (1.08 KB)
# Trainable params: 276 (1.08 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(X_train_trf,y_train,batch_size=50,epochs=100,verbose=1,validation_split=0.2)
# Out:
# Epoch 1/100
# 128/128 [==============================] - 1s 2ms/step - loss: 0.5294 - accuracy: 0.7958 - val_loss: 0.4954 - val_accuracy: 0.7969
# Epoch 2/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4918 - accuracy: 0.7958 - val_loss: 0.4856 - val_accuracy: 0.7969
# Epoch 3/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.4803 - accuracy: 0.7958 - val_loss: 0.4731 - val_accuracy: 0.7969
# Epoch 4/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4659 - accuracy: 0.7958 - val_loss: 0.4584 - val_accuracy: 0.7969
# Epoch 5/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4511 - accuracy: 0.7958 - val_loss: 0.4465 - val_accuracy: 0.7969
# Epoch 6/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4394 - accuracy: 0.7978 - val_loss: 0.4387 - val_accuracy: 0.7987
# Epoch 7/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4324 - accuracy: 0.8053 - val_loss: 0.4345 - val_accuracy: 0.8112
# Epoch 8/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4285 - accuracy: 0.8094 - val_loss: 0.4325 - val_accuracy: 0.8075
# Epoch 9/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4260 - accuracy: 0.8108 - val_loss: 0.4316 - val_accuracy: 0.8106
# Epoch 10/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.4247 - accuracy: 0.8122 - val_loss: 0.4307 - val_accuracy: 0.8075
# Epoch 11/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.4238 - accuracy: 0.8128 - val_loss: 0.4300 - val_accuracy: 0.8069
# Epoch 12/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4227 - accuracy: 0.8136 - val_loss: 0.4293 - val_accuracy: 0.8081
# Epoch 13/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4220 - accuracy: 0.8114 - val_loss: 0.4283 - val_accuracy: 0.8081
# Epoch 14/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.4211 - accuracy: 0.8159 - val_loss: 0.4276 - val_accuracy: 0.8094
# Epoch 15/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.4203 - accuracy: 0.8158 - val_loss: 0.4266 - val_accuracy: 0.8112
# Epoch 16/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.4196 - accuracy: 0.8184 - val_loss: 0.4257 - val_accuracy: 0.8119
# Epoch 17/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4187 - accuracy: 0.8198 - val_loss: 0.4247 - val_accuracy: 0.8156
# Epoch 18/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4175 - accuracy: 0.8217 - val_loss: 0.4239 - val_accuracy: 0.8156
# Epoch 19/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4168 - accuracy: 0.8216 - val_loss: 0.4227 - val_accuracy: 0.8206
# Epoch 20/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4156 - accuracy: 0.8238 - val_loss: 0.4218 - val_accuracy: 0.8250
# Epoch 21/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4146 - accuracy: 0.8247 - val_loss: 0.4206 - val_accuracy: 0.8238
# Epoch 22/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4136 - accuracy: 0.8266 - val_loss: 0.4196 - val_accuracy: 0.8275
# Epoch 23/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4128 - accuracy: 0.8269 - val_loss: 0.4185 - val_accuracy: 0.8263
# Epoch 24/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4115 - accuracy: 0.8294 - val_loss: 0.4170 - val_accuracy: 0.8263
# Epoch 25/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4103 - accuracy: 0.8289 - val_loss: 0.4157 - val_accuracy: 0.8300
# Epoch 26/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4091 - accuracy: 0.8297 - val_loss: 0.4144 - val_accuracy: 0.8288
# Epoch 27/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4078 - accuracy: 0.8308 - val_loss: 0.4128 - val_accuracy: 0.8313
# Epoch 28/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.4063 - accuracy: 0.8322 - val_loss: 0.4114 - val_accuracy: 0.8313
# Epoch 29/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4049 - accuracy: 0.8320 - val_loss: 0.4101 - val_accuracy: 0.8294
# Epoch 30/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.4035 - accuracy: 0.8334 - val_loss: 0.4084 - val_accuracy: 0.8313
# Epoch 31/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.4019 - accuracy: 0.8330 - val_loss: 0.4069 - val_accuracy: 0.8331
# Epoch 32/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.4003 - accuracy: 0.8348 - val_loss: 0.4053 - val_accuracy: 0.8331
# Epoch 33/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3988 - accuracy: 0.8353 - val_loss: 0.4038 - val_accuracy: 0.8363
# Epoch 34/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.3970 - accuracy: 0.8348 - val_loss: 0.4023 - val_accuracy: 0.8350
# Epoch 35/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.3954 - accuracy: 0.8370 - val_loss: 0.4008 - val_accuracy: 0.8388
# Epoch 36/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3934 - accuracy: 0.8348 - val_loss: 0.3992 - val_accuracy: 0.8350
# Epoch 37/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.3918 - accuracy: 0.8372 - val_loss: 0.3976 - val_accuracy: 0.8388
# Epoch 38/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.3900 - accuracy: 0.8386 - val_loss: 0.3959 - val_accuracy: 0.8381
# Epoch 39/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3883 - accuracy: 0.8377 - val_loss: 0.3947 - val_accuracy: 0.8369
# Epoch 40/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.3865 - accuracy: 0.8386 - val_loss: 0.3928 - val_accuracy: 0.8400
# Epoch 41/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3847 - accuracy: 0.8403 - val_loss: 0.3914 - val_accuracy: 0.8381
# Epoch 42/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3828 - accuracy: 0.8409 - val_loss: 0.3899 - val_accuracy: 0.8394
# Epoch 43/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3810 - accuracy: 0.8423 - val_loss: 0.3885 - val_accuracy: 0.8413
# Epoch 44/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3796 - accuracy: 0.8416 - val_loss: 0.3871 - val_accuracy: 0.8400
# Epoch 45/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.3777 - accuracy: 0.8439 - val_loss: 0.3859 - val_accuracy: 0.8394
# Epoch 46/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3759 - accuracy: 0.8438 - val_loss: 0.3845 - val_accuracy: 0.8400
# Epoch 47/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.3744 - accuracy: 0.8438 - val_loss: 0.3832 - val_accuracy: 0.8450
# Epoch 48/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3727 - accuracy: 0.8466 - val_loss: 0.3820 - val_accuracy: 0.8450
# Epoch 49/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.3713 - accuracy: 0.8470 - val_loss: 0.3812 - val_accuracy: 0.8456
# Epoch 50/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.3701 - accuracy: 0.8477 - val_loss: 0.3799 - val_accuracy: 0.8450
# Epoch 51/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.3688 - accuracy: 0.8477 - val_loss: 0.3791 - val_accuracy: 0.8481
# Epoch 52/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3672 - accuracy: 0.8489 - val_loss: 0.3781 - val_accuracy: 0.8475
# Epoch 53/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3659 - accuracy: 0.8489 - val_loss: 0.3772 - val_accuracy: 0.8475
# Epoch 54/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3646 - accuracy: 0.8511 - val_loss: 0.3765 - val_accuracy: 0.8469
# Epoch 55/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.3635 - accuracy: 0.8495 - val_loss: 0.3755 - val_accuracy: 0.8469
# Epoch 56/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3624 - accuracy: 0.8520 - val_loss: 0.3751 - val_accuracy: 0.8456
# Epoch 57/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3616 - accuracy: 0.8522 - val_loss: 0.3746 - val_accuracy: 0.8450
# Epoch 58/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3602 - accuracy: 0.8517 - val_loss: 0.3738 - val_accuracy: 0.8462
# Epoch 59/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.3593 - accuracy: 0.8542 - val_loss: 0.3731 - val_accuracy: 0.8487
# Epoch 60/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.3584 - accuracy: 0.8531 - val_loss: 0.3726 - val_accuracy: 0.8500
# Epoch 61/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3575 - accuracy: 0.8536 - val_loss: 0.3723 - val_accuracy: 0.8469
# Epoch 62/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3567 - accuracy: 0.8550 - val_loss: 0.3719 - val_accuracy: 0.8462
# Epoch 63/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3559 - accuracy: 0.8550 - val_loss: 0.3714 - val_accuracy: 0.8481
# Epoch 64/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.3553 - accuracy: 0.8555 - val_loss: 0.3709 - val_accuracy: 0.8494
# Epoch 65/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.3543 - accuracy: 0.8583 - val_loss: 0.3711 - val_accuracy: 0.8475
# Epoch 66/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.3534 - accuracy: 0.8562 - val_loss: 0.3701 - val_accuracy: 0.8494
# Epoch 67/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.3528 - accuracy: 0.8584 - val_loss: 0.3699 - val_accuracy: 0.8531
# Epoch 68/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3527 - accuracy: 0.8584 - val_loss: 0.3695 - val_accuracy: 0.8500
# Epoch 69/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3515 - accuracy: 0.8575 - val_loss: 0.3691 - val_accuracy: 0.8519
# Epoch 70/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3509 - accuracy: 0.8592 - val_loss: 0.3689 - val_accuracy: 0.8500
# Epoch 71/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3504 - accuracy: 0.8570 - val_loss: 0.3691 - val_accuracy: 0.8512
# Epoch 72/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.3498 - accuracy: 0.8591 - val_loss: 0.3680 - val_accuracy: 0.8512
# Epoch 73/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3490 - accuracy: 0.8592 - val_loss: 0.3686 - val_accuracy: 0.8519
# Epoch 74/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.3484 - accuracy: 0.8614 - val_loss: 0.3677 - val_accuracy: 0.8506
# Epoch 75/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3480 - accuracy: 0.8608 - val_loss: 0.3677 - val_accuracy: 0.8531
# Epoch 76/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3475 - accuracy: 0.8600 - val_loss: 0.3678 - val_accuracy: 0.8519
# Epoch 77/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3471 - accuracy: 0.8617 - val_loss: 0.3680 - val_accuracy: 0.8519
# Epoch 78/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3467 - accuracy: 0.8612 - val_loss: 0.3665 - val_accuracy: 0.8525
# Epoch 79/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3462 - accuracy: 0.8620 - val_loss: 0.3666 - val_accuracy: 0.8512
# Epoch 80/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3461 - accuracy: 0.8608 - val_loss: 0.3663 - val_accuracy: 0.8506
# Epoch 81/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3453 - accuracy: 0.8617 - val_loss: 0.3662 - val_accuracy: 0.8531
# Epoch 82/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.3449 - accuracy: 0.8620 - val_loss: 0.3659 - val_accuracy: 0.8531
# Epoch 83/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.3444 - accuracy: 0.8622 - val_loss: 0.3656 - val_accuracy: 0.8519
# Epoch 84/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.3438 - accuracy: 0.8630 - val_loss: 0.3661 - val_accuracy: 0.8525
# Epoch 85/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3444 - accuracy: 0.8623 - val_loss: 0.3650 - val_accuracy: 0.8500
# Epoch 86/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.3432 - accuracy: 0.8609 - val_loss: 0.3650 - val_accuracy: 0.8512
# Epoch 87/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.3429 - accuracy: 0.8616 - val_loss: 0.3646 - val_accuracy: 0.8500
# Epoch 88/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.3431 - accuracy: 0.8619 - val_loss: 0.3648 - val_accuracy: 0.8531
# Epoch 89/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3424 - accuracy: 0.8625 - val_loss: 0.3644 - val_accuracy: 0.8519
# Epoch 90/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.3420 - accuracy: 0.8628 - val_loss: 0.3640 - val_accuracy: 0.8512
# Epoch 91/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3416 - accuracy: 0.8625 - val_loss: 0.3640 - val_accuracy: 0.8506
# Epoch 92/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3414 - accuracy: 0.8625 - val_loss: 0.3639 - val_accuracy: 0.8506
# Epoch 93/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.3409 - accuracy: 0.8628 - val_loss: 0.3633 - val_accuracy: 0.8506
# Epoch 94/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3406 - accuracy: 0.8636 - val_loss: 0.3635 - val_accuracy: 0.8519
# Epoch 95/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.3405 - accuracy: 0.8633 - val_loss: 0.3632 - val_accuracy: 0.8531
# Epoch 96/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.3399 - accuracy: 0.8645 - val_loss: 0.3630 - val_accuracy: 0.8512
# Epoch 97/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3400 - accuracy: 0.8630 - val_loss: 0.3630 - val_accuracy: 0.8512
# Epoch 98/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.3397 - accuracy: 0.8636 - val_loss: 0.3632 - val_accuracy: 0.8519
# Epoch 99/100
# 128/128 [==============================] - 0s 2ms/step - loss: 0.3392 - accuracy: 0.8637 - val_loss: 0.3626 - val_accuracy: 0.8537
# Epoch 100/100
# 128/128 [==============================] - 0s 1ms/step - loss: 0.3391 - accuracy: 0.8639 - val_loss: 0.3626 - val_accuracy: 0.8512

# %%
y_pred = model.predict(X_test_trf)
# Out:
# 63/63 [==============================] - 0s 1ms/step

# %%
y_pred
# Out:
# array([[0.21173312],
#        [0.30314243],
#        [0.09810665],
#        ...,
#        [0.09475027],
#        [0.12817338],
#        [0.253033  ]], dtype=float32)

# %%
y_pred = y_pred.argmax(axis=-1)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.7975

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
